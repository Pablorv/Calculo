# %% [markdown]
# ### Ejemplos de supremos e ínfimos.
#
# ¿Qué es un supremo?
#
# a) Tiene que ser una cota superior (es decir, un elemento que acote al conjunto de interés).
#
# b) Tiene que ser la más pequeña de ellas.
#
# 1) ${\displaystyle \sup\{1,2,3\}=3\,}$
#
# **Dem.**
#
# 1) Queremos probar que $3$ es una cota superior de $A=\{1,2,3\}$.
#
# Esto es verdad porque $1 \leq 2 \leq 3$, $3\leq 3$.
#
# Por lo tanto 3 es cota superior.
#
# 2) Lo haremos por contradicción.
#
# Es decir, supondremos que 3 no es la más pequeña de las cotas superiores, *i.e*
#  existe un $a<3$ tal que $a$ es cota superior.
#
# Como $a$ es cota superior, $\forall$ $x\in A$ $x\leq a$. En particular $3\leq a$. (*absurdo*).
#
# Por lo tanto 3 sí es la más pequeña de las cotas superiores,
#
#
#
#
#
#
# ${\displaystyle \inf\{1,2,3\}=1\,}$
#
#
#
# ${\displaystyle \sup\{x\in \mathbb {R} |0<x<1\}=\sup\{x\in \mathbb {R} |0\leq x\leq 1\}=1\,}$
#
#
# Consideremos cierto que si $A\subseteq B$ y $sup(A)$ y $sup(B)$ existen, entonces $sup(A)\leq sup(B)$.
#
# ${\displaystyle \inf\{x\in \mathbb {R} |0<x<1\}=\inf\{x\in \mathbb {R} |0\leq x\leq 1\}=0\,}$
#
#
# ${\displaystyle \sup\{x\in \mathbb {Q^{+}} |x^{2}\leq 2\}={\sqrt {2}}\,}$
#
#
# ${\displaystyle \inf\{x\in \mathbb {Q^{+}} |x^{2}<2\}=0\,}$
#
#
# ${\displaystyle \sup\{(-1)^{n}-{\frac {1}{n}}|n\in \mathbb {N} \}=1\,}$
#
#
# ${\displaystyle \inf\{{\frac {1}{n}}|n\in \mathbb {N} \}=0\,}$

# %% [markdown]
# ### Ejemplos de sucesiones
#
#
# 1) $a_{n}= c$ con $c\in \mathbb{R}$,

# %% [markdown]
# $$
# \lim_{n\rightarrow \infty} a_{n}= c
# $$
#
#
# **Dem.**
#
# Sea $\varepsilon >0$ toma $n_{0}=n $
#
#
# tal que si $n>n_{0}$
#
# se cumple que $|a_{n}-L|=|c-L|=|c-c|=|0|=0< \varepsilon$

# %% [markdown]
# 2) $a_{n}= n$
#
# **Def.**
#
# Decimos que una sucesión $diverge$ si para todo $M \in \mathbb{R}$ existe $n\in \mathbb{N}$ tal que $a_{n}\geq M$, en este caso
#
#
# $$
# \lim_{n\rightarrow \infty} a_{n}=\infty
# $$
#
#
#
#
# 3) $a_{n}= \frac{1}{n}$
#
# $$
# \lim_{n\rightarrow \infty} \frac{1}{n}=0
# $$
#
#
#
# **Dem.**
#
# Sea $\varepsilon >0$ toma $n_{0}= \frac{2}{\varepsilon}$
#
# tal que si $n\geq n_{0}$, se cumple que
#
# $|a_{n}-L|=|\frac{1}{n}|\leq |\frac{1}{n_{0}}|=\frac{\varepsilon}{2}< \varepsilon$.

# %% [markdown]
# $2\leq 3$
#
#
# $\frac{1}{2}\geq \frac{1}{3}$
#
# si $|n| \geq |n_{0}|$, entonces $|\frac{1}{n}|\leq |\frac{1}{n_{0}}|$

# %% [markdown]
# 4) $a_{n}= (-1)^{n}$
#
# 5) $a_{n}= 2^{n}$
#
# 6) $a_{n}= \left(1+\frac{1}{n}\right)^{n}$
#
# 7) $a_{n}= e^{in\pi} = cos(n\pi)+isin(n\pi)=cos(n\pi)$
#
# 8) Sucesión de Fibonnaci y número de oro $\phi$: $a_{0}=0$, $a_{1}=1$ y $a_{n}=a_{n-1}+a_{n-2}$
#
# $\{1,1,2,3,5,8,13,21,34,... \}$

# %% [markdown]
# **Definición.** Decimos que una sucesión es creciente si
# $$
# a_{n}\leq a_{n+1}
# $$
#
# y estrictamente creciente si
#
# $$
# a_{n}< a_{n+1}
# $$
#
# Así mismo, decimos que una sucesión es decreciente si
#
#
# $$
# a_{n}\geq a_{n+1}
# $$
#
# y estrictamente decreciente si
#
# $$
# a_{n}> a_{n+1}
# $$
#
# Decimos que una sucesión es monótona si es creciente o decreciente y estrictamente monónota si es estrictamente creciente o decreciente.

# %% [markdown]
# **Proposición.** Sea $A\subseteq \mathbb{R}$ no vacío. Si $s=sup(A)$, entonces existe una sucesión creciente de elementos de $A$, $\{a_{n}\}$, tal que $\lim_{n\rightarrow \infty} a_{n}=s$. Si $s\notin A$, entonces la sucesión puede ser estrictamente creciente.
#
#
# **Dem.**
#
#
# Si $s\in A$, tomamos $a_{n}=s$ y la sucesión constante (s), es creciente.
#
#
# Si $s\notin A$, tenemos que ir construyendo término a término los elementos de $\{a_{n}\}$. Como $A$ no es vacío, tiene al menos un elemento, $\textbf{a}_{1}\in A$. Tomemos $a_{1}=\textbf{a}_{1}$. Ahora, consideremos $\textbf{a}_{2}=\frac{a_{1}+s}{2}$, que es un número que es $\textbf{a}_{2}<s$. Entonces existe $a_{2}\in A$ tal que $\textbf{a}_{2}<a_{2}<s$, y así sucesivamente.
#
# De tal modo que el enésimo término de la sucesión, estará dado como el número que cumple que
#
# $$\textbf{a}_{n}<a_{n}<s,$$
#
# donde $\textbf{a}_{n}= \frac{a_{n-1}+s}{2}$.
#
# Vemos que $\{a_{n}\}$ es creciente, pues $a_{n}>\textbf{a}_{n}>a_{n-1}$.
#
#
# Ahora falta demostrar que $\lim_{n\rightarrow \infty}a_{n}=s$.
#
#
#
# Sea $\varepsilon>0$
#
# Usemos el truco de que si $\{a_{n}\}$ es creciente, entonces basta probar que
#
# $0<L-a_{n}<\varepsilon$
#
# Para hacerlo veamos que
#
#
# $0< s-a_{n}<\frac{s-a_{n-1}}{2}< \frac{s-a_{n-2}}{2^2}<\frac{s-a_{n-3}}{2^3}<...<\frac{s-a_{1}}{2^{n-1}}<\varepsilon$,
#
# donde en el último paso, hemos usado que
#
#
# $$\lim_{n\rightarrow \infty} \frac{1}{2^{n}}=0$$
#
#
# Es decir que $\forall \varepsilon>0$, $\frac{1}{2^{n}}<\varepsilon$.
#
# (Hay que demostrarlo!)
#
#
# i.e falta ver que, dada $\varepsilon >0$, tenemos que, existe una $n_{0}\in \mathbb{N}$ tal que si $n\geq n_{0}$, entonces $\frac{1}{2^{n}}<\varepsilon$

# %% [markdown]
# Una vez que hemos terminado de revisar (muy rápidamente) a las sucesiones, sigamos con el estudio de las funciones.
# Ahora, aprendamos a hacer la *gráfica* de una función.

# %% [markdown]
# **Definición.** Sean $A,B\subseteq \mathbb{R}$ y $f:A\rightarrow B$ una función. La *gráfica* de una función es el conjunto
# $Graf(f)=\{(x,f(x))|x\in A \quad \text{y} \quad f(x)\in B \} \subseteq A\times B$.

# %% [markdown]
# Para ahondar más en el tema, primero definamos el *espacio* en el que vamos a trabajar en este curso de cálculo.
#
# El lugar geométrico en el cual vamos a trabajar está dado por
#
# $$ \mathbb{R}^{2}\equiv \{(x,y)|x,y \in \mathbb{R} \}. $$
#
#
# Es decir, para cualquier función de la forma $f:\mathbb{R}\rightarrow \mathbb{R}$, $Graf(f)\subseteq \mathbb{R}^{2}$. $\mathbb{R}^{2}$ es un *plano*, el cual está formado por dos líneas rectas, una vertical, llamada el eje de las ordenadas y una horizontal, llamada el eje de las abcisas.
#
# Visualizar geométricamente a la función $f$ es posible al dibujar con un punto cada elemento de $Graf(f)$.
#
# **Ejemplos.**
#
#
# 1) $f:\mathbb{R}:\rightarrow \mathbb{R}$, $f(x)=cx$, con $c\in \mathbb{R}$.
#
# Son rectas que pasan por el origen y tienen pendiente $c$.
#
# 2) $f:\mathbb{R}:\rightarrow \mathbb{R}$, $f(x)=x^n$, con $n\in \mathbb{N}$.
#
# 3) $f:\mathbb{R}:\rightarrow \mathbb{R}$, $f(x)=sin(nx)$, con $n\in \mathbb{Z}$.
#
# 4) $f:\mathbb{R}:\rightarrow \mathbb{R}$, $f(x)=sin(x+a)$, con $a\in \mathbb{R}$.
#
# 5) $f:\mathbb{R}:\rightarrow \mathbb{R}$, $f(x)=e^{ax}$, con $a\in \mathbb{R}$.
#
# 6) $f:\mathbb{R}:\rightarrow \mathbb{R}$, $f(x)=ln(ax)$, con $a\in \mathbb{R}$.

# %% [markdown]
# Algunos tipos interesantes de funciones:
#
# Funciones pares. Son funciones tales que se cumple para cualquier $x\in Dom(f)$ que, $f(-x)=f(x)$.
#
# Por ejemplo:
#
#
# Funciones impares: Son funciones tales que se cumple para cualquier $x\in Dom(f)$ que, $f(-x)=-f(x)$
#
# Por ejemplo:
#
#
# Funciones periódicas: Son funciones tales que para cualquier $x\in Dom(f)$ se tiene que para algún $L \in \mathbb{R}$, se cumple que $f(x+L)=f(x)$. $L$ se llama el *periodo de la función*.
#
# Por ejemplo:
